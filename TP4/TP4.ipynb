# %%
import numpy as np
import os
import random
import time
np.random.seed(123)  # for reproducibility
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Model, Input
from tensorflow.keras.layers import Dense, Flatten, Dropout, Convolution2D, MaxPooling2D, Reshape, Conv2DTranspose
from tensorflow.keras.datasets.mnist import load_data
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt



from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import tensorflow as tf
from tensorflow.keras import Sequential, Model, Input
from tensorflow.keras.layers import Conv2DTranspose, Reshape, Dense, Activation,Flatten, Dropout, Convolution2D, MaxPooling2D, Input
from utilitaire import affiche


##################################################
# I - Load pre-shuffled MNIST data train and test sets
##################################################
from tensorflow.keras.datasets.mnist import load_data
from matplotlib import pyplot

# %%
# Chargement et mise en forme des données
DATA_PATH = 'Data1/Data'
categories=["accordion", "anchor", "barrel", "binocular"]
for i in range(len(categories)):
    categories[i]=DATA_PATH + '/'+categories[i]
data = []

print(categories)

# %%
data = []
for c, category in enumerate(categories):
    images = [os.path.join(dp, f) for dp, dn, filenames in os.walk(category)
        for f in filenames if os.path.splitext(f)[1].lower() in ['.jpg', '.png', '.jpeg']]
    for img_path in images:
        img = tf.keras.preprocessing.image.load_img(img_path, target_size=(224, 224))
        x=np.array(img)
        x = np.expand_dims(x, axis=0)
        data.append({'x': np.array(x[0]), 'y':c})

num_classes = len(categories)
print("===========================================")
print(num_classes)
print("===========================================")
print(len(data))
print(data[0]['x'].shape)

# %%
random.shuffle(data)
#create train / val / test split
train_split = 0.7
idx_train = int(train_split * len(data))
train = data[:idx_train]
test = data[idx_train:]
#separate data and labels
X_train, y_train = np.array([t['x'] for t in train]), [t['y'] for t in train]
X_test, y_test = np.array([t['x'] for t in test]), [t['y'] for t in test]
#normalize data
X_train = X_train.astype("float32") / 255.0
X_test = X_test.astype("float32") / 255.0
#convert labels to one-hot vectors
Y_train = tf.keras.utils.to_categorical(y_train, num_classes)
Y_test = tf.keras.utils.to_categorical(y_test, num_classes)
print('finished loading',len(data),'images from',num_classes,'categories')
print('train / test split:', len(X_train), len(X_test))
print('training data shape: ', X_train.shape)
print('training label shape: ', len(y_train))

# %% [markdown]
# - X_train a une taille de 123
# - X_test a une taille de 54
#
# - y_train a une taille de 123
# - y_test a une taille de 54
#
#
# On a fait un pre processing des données pour avoir la même taille pour les données d'entrainement et de test.

# %%
print(X_train.shape)

# %% [markdown]
# # image de taille 224x224*3 car RGB

# %%
#affichage des images
plt.figure(figsize=(10,10))
for i in range(3):
    plt.subplot(1,3,i+1)
    plt.imshow(X_train[i])
    plt.axis('off')

    print("taille de l'image : ", X_train[i].shape)

# %% [markdown]
# # Apprentissage d'un modele convolutif
#
# 1) Input ==> image
# 2) Convolution filtre 3x3
# 3) Convolution filtre 3x3
# 4) Flatten
# 5) couches fully connected 256
# 6) couches fully connected 256
# 7) softmax

# %%
#input = taille de l'image
inputs = Input(shape=(224, 224, 3))
x = inputs


x=Convolution2D(32, kernel_size=(3,3), activation='relu')(x)
x=MaxPooling2D(pool_size=(2,2),strides=2)(x)

x=Convolution2D(64, kernel_size=(3,3), activation='relu')(x)
x=MaxPooling2D(pool_size=(2,2),strides=2)(x)

x=Flatten()(x)
x=Dense(256, activation='relu')(x)
outputs=Dense(4, activation='softmax')(x)

model_CNN = Model(inputs, outputs)

print("Nombre de paramètres : ", model_CNN.count_params())

model_CNN.summary()

# %% [markdown]
# # Entrainement
#
# Ajouter un stride permet de diminuer le nombre de paramètres.

# %%
lr= 0.01
batch_size= 64
epochs=50

sgd1= tf.keras.optimizers.SGD(learning_rate=lr, momentum=0.9)

model_CNN.compile(loss='categorical_crossentropy', optimizer=sgd1, metrics=['accuracy'])
tps1 = time.time()


history =model_CNN.fit(X_train, Y_train, batch_size=batch_size, epochs=epochs, verbose=1,validation_data=(X_test, Y_test))
affiche(history)

# Evaluation du modèle sur les données de test
score = model_CNN.evaluate(X_test, Y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

y_pred = model_CNN.predict(X_test)
y_pred = y_pred.argmax(axis=-1)
print('Confusion Matrix')
print(confusion_matrix(y_test, y_pred))
# Out:
# Epoch 1/50
# 2/2 [==============================] - 4s 2s/step - loss: 1.4519 - accuracy: 0.2683 - val_loss: 1.3794 - val_accuracy: 0.2963
# Epoch 2/50
# 2/2 [==============================] - 3s 2s/step - loss: 1.3564 - accuracy: 0.2358 - val_loss: 1.2282 - val_accuracy: 0.5741
# Epoch 3/50
# 2/2 [==============================] - 3s 2s/step - loss: 1.0698 - accuracy: 0.6504 - val_loss: 1.0871 - val_accuracy: 0.5185
# Epoch 4/50
# 2/2 [==============================] - 3s 2s/step - loss: 0.9100 - accuracy: 0.6341 - val_loss: 0.9415 - val_accuracy: 0.5556
# Epoch 5/50
# 2/2 [==============================] - 3s 2s/step - loss: 0.7062 - accuracy: 0.7480 - val_loss: 0.9439 - val_accuracy: 0.5741
# Epoch 6/50
# 2/2 [==============================] - 3s 2s/step - loss: 0.6085 - accuracy: 0.7642 - val_loss: 1.2783 - val_accuracy: 0.5926
# Epoch 7/50
# 2/2 [==============================] - 3s 2s/step - loss: 0.9705 - accuracy: 0.6667 - val_loss: 1.3329 - val_accuracy: 0.4630
# Epoch 8/50
# 2/2 [==============================] - 3s 2s/step - loss: 0.7030 - accuracy: 0.7073 - val_loss: 0.8678 - val_accuracy: 0.6481
# Epoch 9/50
# 2/2 [==============================] - 3s 2s/step - loss: 0.5738 - accuracy: 0.7967 - val_loss: 0.9302 - val_accuracy: 0.6296
# Epoch 10/50
# 2/2 [==============================] - 3s 2s/step - loss: 0.5956 - accuracy: 0.7886 - val_loss: 0.8206 - val_accuracy: 0.6481
# Epoch 11/50
# 2/2 [==============================] - 3s 2s/step - loss: 0.4024 - accuracy: 0.8943 - val_loss: 0.7266 - val_accuracy: 0.6667
# Epoch 12/50
# 2/2 [==============================] - 3s 2s/step - loss: 0.3086 - accuracy: 0.8780 - val_loss: 0.8255 - val_accuracy: 0.7037
# Epoch 13/50
# 2/2 [==============================] - 3s 2s/step - loss: 0.2364 - accuracy: 0.9024 - val_loss: 1.1853 - val_accuracy: 0.6296
# Epoch 14/50
# 2/2 [==============================] - 3s 2s/step - loss: 0.2256 - accuracy: 0.8780 - val_loss: 1.6924 - val_accuracy: 0.6296
# Epoch 15/50
# 2/2 [==============================] - 4s 2s/step - loss: 0.5383 - accuracy: 0.8374 - val_loss: 3.4426 - val_accuracy: 0.5741
# Epoch 16/50
# 2/2 [==============================] - 4s 2s/step - loss: 1.1741 - accuracy: 0.7724 - val_loss: 1.2319 - val_accuracy: 0.5000
# Epoch 17/50
# 2/2 [==============================] - 4s 2s/step - loss: 0.5393 - accuracy: 0.7561 - val_loss: 1.0835 - val_accuracy: 0.5370
# Epoch 18/50
# 2/2 [==============================] - 4s 2s/step - loss: 0.6745 - accuracy: 0.7317 - val_loss: 0.9709 - val_accuracy: 0.5556
# Epoch 19/50
# 2/2 [==============================] - 4s 2s/step - loss: 0.4718 - accuracy: 0.8943 - val_loss: 0.9484 - val_accuracy: 0.5556
# Epoch 20/50
# 2/2 [==============================] - 4s 2s/step - loss: 0.3873 - accuracy: 0.8537 - val_loss: 1.0154 - val_accuracy: 0.6296
# Epoch 21/50
# 2/2 [==============================] - 4s 2s/step - loss: 0.2825 - accuracy: 0.9106 - val_loss: 1.3258 - val_accuracy: 0.5926
# Epoch 22/50
# 2/2 [==============================] - 4s 2s/step - loss: 0.1946 - accuracy: 0.9431 - val_loss: 1.4657 - val_accuracy: 0.5556
# Epoch 23/50
# 2/2 [==============================] - 4s 2s/step - loss: 0.2497 - accuracy: 0.9106 - val_loss: 1.5284 - val_accuracy: 0.6667
# Epoch 24/50
# 2/2 [==============================] - 4s 2s/step - loss: 0.1760 - accuracy: 0.9268 - val_loss: 3.0620 - val_accuracy: 0.4444
# Epoch 25/50
# 2/2 [==============================] - 4s 2s/step - loss: 0.1992 - accuracy: 0.9187 - val_loss: 1.6439 - val_accuracy: 0.5741
# Epoch 26/50
# 2/2 [==============================] - 4s 2s/step - loss: 0.1424 - accuracy: 0.9431 - val_loss: 1.4242 - val_accuracy: 0.5741
# Epoch 27/50
# 2/2 [==============================] - 4s 2s/step - loss: 0.0933 - accuracy: 0.9675 - val_loss: 1.1785 - val_accuracy: 0.5926
# Epoch 28/50
# 2/2 [==============================] - 4s 2s/step - loss: 0.0472 - accuracy: 1.0000 - val_loss: 1.1965 - val_accuracy: 0.6481
# Epoch 29/50
# 2/2 [==============================] - 4s 2s/step - loss: 0.0564 - accuracy: 1.0000 - val_loss: 1.1517 - val_accuracy: 0.6296
# Epoch 30/50
# 2/2 [==============================] - 4s 2s/step - loss: 0.0411 - accuracy: 1.0000 - val_loss: 1.2843 - val_accuracy: 0.6111
# Epoch 31/50
# 2/2 [==============================] - 4s 2s/step - loss: 0.0349 - accuracy: 1.0000 - val_loss: 1.2299 - val_accuracy: 0.6481
# Epoch 32/50
# 2/2 [==============================] - 4s 2s/step - loss: 0.0187 - accuracy: 1.0000 - val_loss: 1.2542 - val_accuracy: 0.6667
# Epoch 33/50
# 2/2 [==============================] - 4s 2s/step - loss: 0.0149 - accuracy: 1.0000 - val_loss: 1.4410 - val_accuracy: 0.6481
# Epoch 34/50
# 2/2 [==============================] - 4s 2s/step - loss: 0.0142 - accuracy: 1.0000 - val_loss: 1.5468 - val_accuracy: 0.6481
# Epoch 35/50
# 2/2 [==============================] - 4s 2s/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 1.6629 - val_accuracy: 0.6481
# Epoch 36/50
# 2/2 [==============================] - 4s 2s/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 1.8043 - val_accuracy: 0.6296
# Epoch 37/50
# 2/2 [==============================] - 4s 2s/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 1.8780 - val_accuracy: 0.6667
# Epoch 38/50
# 2/2 [==============================] - 4s 2s/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 1.9153 - val_accuracy: 0.6481
# Epoch 39/50
# 2/2 [==============================] - 4s 2s/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 1.9447 - val_accuracy: 0.6481
# Epoch 40/50
# 2/2 [==============================] - 4s 2s/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 1.9670 - val_accuracy: 0.6667
# Epoch 41/50
# 2/2 [==============================] - 4s 2s/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.9946 - val_accuracy: 0.6852
# Epoch 42/50
# 2/2 [==============================] - 4s 2s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 2.0219 - val_accuracy: 0.6852
# Epoch 43/50
# 2/2 [==============================] - 4s 2s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 2.0504 - val_accuracy: 0.6852
# Epoch 44/50
# 2/2 [==============================] - 4s 2s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 2.0786 - val_accuracy: 0.7037
# Epoch 45/50
# 2/2 [==============================] - 4s 2s/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 2.1033 - val_accuracy: 0.7037
# Epoch 46/50
# 2/2 [==============================] - 4s 3s/step - loss: 9.5101e-04 - accuracy: 1.0000 - val_loss: 2.1243 - val_accuracy: 0.7222
# Epoch 47/50
# 2/2 [==============================] - 5s 2s/step - loss: 8.6812e-04 - accuracy: 1.0000 - val_loss: 2.1433 - val_accuracy: 0.7222
# Epoch 48/50
# 2/2 [==============================] - 5s 2s/step - loss: 7.9206e-04 - accuracy: 1.0000 - val_loss: 2.1598 - val_accuracy: 0.7222
# Epoch 49/50
# 2/2 [==============================] - 4s 2s/step - loss: 7.0806e-04 - accuracy: 1.0000 - val_loss: 2.1753 - val_accuracy: 0.7037
# Epoch 50/50
# 2/2 [==============================] - 4s 2s/step - loss: 6.5809e-04 - accuracy: 1.0000 - val_loss: 2.1895 - val_accuracy: 0.7037
# Test loss: 2.189526081085205
# Test accuracy: 0.7037037014961243
# 2/2 [==============================] - 0s 160ms/step
# Confusion Matrix
# [[15  0  1  0]
#  [ 0  8  4  0]
#  [ 0  7  8  1]
#  [ 0  2  1  7]]

# %%
affiche(history)
print('Test accuracy:', score[1])
# Out:
# Test accuracy: 0.7037037014961243

# %% [markdown]
# # Transfert Learning
#
# VGG a été appris sur Image Net
# Pour nous, on va recuperer les parametres ,sauf celle de la derniere couche, et on va les utiliser pour notre probleme.

# %%
input_tensor = Input(shape=(224,224,3))

model = tf.keras.applications.VGG16(weights='imagenet',include_top=False,input_tensor=input_tensor)
model.summary()
#extraction des features
feature_train = model.predict(X_train)
feature_test = model.predict(X_test)
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_22 (InputLayer)       [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14714688 (56.13 MB)
# Trainable params: 14714688 (56.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 4/4 [==============================] - 15s 4s/step
# 2/2 [==============================] - 9s 5s/step

# %% [markdown]
# On a donc extrait :
#
# - feature_train : les features de l'ensemble d'entrainement
# - feature_test : les features de l'ensemble de test
#
# Cela signifie que l'on a fait passer les images dans le reseau VGG et on a recuperer les features de la couche avant la derniere couche.

# %%
print(feature_train.shape)
print(feature_test.shape)
# Out:
# (123, 7, 7, 512)
# (54, 7, 7, 512)

# %%
#visualisation des features
plt.figure(figsize=(10,10))

#il faut prendre 1 image sur la profondeur
for i in range(3):
    plt.subplot(1,3,i+1)
    plt.imshow(feature_train[i,:,:,0])
    plt.axis('off')

    print("taille de l'image : ", feature_train[i,:,:,0].shape)
# Out:
# taille de l'image :  (7, 7)
# taille de l'image :  (7, 7)
# taille de l'image :  (7, 7)

# %% [markdown]
# Construire un réseau MLP à une couche cachée qui prend en entrée ces caractéristiques et prédit la classe des images.

# %%
#construction du modèle

input = Input(shape=(7,7,512))
x = input
x = Flatten()(x)
x = Dense(256, activation='relu')(x)
output = Dense(4, activation='softmax')(x)
model = Model(input, output)
print("Nombre de paramètres : ", model.count_params())
# Out:
# Nombre de paramètres :  6423812

# %% [markdown]
# ## Apprentissage

# %%
lr= 0.01
batch_size= 64
epochs=10


sgd1= tf.keras.optimizers.SGD(learning_rate=lr)


model.compile(loss='categorical_crossentropy', optimizer=sgd1, metrics=['accuracy'])
tps1 = time.time()


history =model.fit(feature_train, Y_train, batch_size=batch_size, epochs=epochs, verbose=1,validation_data=(feature_test, Y_test))
tps2 = time.time()

affiche(history)

# Evaluation du modèle sur les données de test
score = model.evaluate(feature_test, Y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Epoch 1/10
# 2/2 [==============================] - 1s 195ms/step - loss: 0.0293 - accuracy: 1.0000 - val_loss: 0.1380 - val_accuracy: 1.0000
# Epoch 2/10
# 2/2 [==============================] - 0s 69ms/step - loss: 0.0288 - accuracy: 1.0000 - val_loss: 0.1384 - val_accuracy: 0.9815
# Epoch 3/10
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0288 - accuracy: 1.0000 - val_loss: 0.1345 - val_accuracy: 1.0000
# Epoch 4/10
# 2/2 [==============================] - 0s 66ms/step - loss: 0.0281 - accuracy: 1.0000 - val_loss: 0.1397 - val_accuracy: 0.9815
# Epoch 5/10
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0271 - accuracy: 1.0000 - val_loss: 0.1359 - val_accuracy: 1.0000
# Epoch 6/10
# 2/2 [==============================] - 0s 71ms/step - loss: 0.0266 - accuracy: 1.0000 - val_loss: 0.1358 - val_accuracy: 0.9815
# Epoch 7/10
# 2/2 [==============================] - 0s 93ms/step - loss: 0.0262 - accuracy: 1.0000 - val_loss: 0.1348 - val_accuracy: 1.0000
# Epoch 8/10
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0257 - accuracy: 1.0000 - val_loss: 0.1349 - val_accuracy: 0.9815
# Epoch 9/10
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0251 - accuracy: 1.0000 - val_loss: 0.1323 - val_accuracy: 1.0000
# Epoch 10/10
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0248 - accuracy: 1.0000 - val_loss: 0.1330 - val_accuracy: 0.9815
# Test loss: 0.13303422927856445
# Test accuracy: 0.9814814925193787

# %% [markdown]
# __Le resultat est meilleur !__

# %% [markdown]
# # Auto encodeur

# %%
(X_train, y_train), (X_test, y_test) = load_data() # Chargement des données de MNIST
X_train, pipo, y_train, pipo = train_test_split(X_train, y_train, test_size=0.9)
X_test, pipo, y_test, pipo = train_test_split(X_test, y_test, test_size=0.9)
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], X_train.shape[2], 1)
#APRES : (60000, 28, 28, 1)

X_test = X_test.reshape(X_test.shape[0], X_train.shape[1], X_train.shape[2], 1)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255


Y_train = tf.keras.utils.to_categorical(y_train, 10)
Y_test = tf.keras.utils.to_categorical(y_test, 10)

# %%
X_train_noise = X_train + 0.2 * np.random.normal(loc=0.0, scale=1.0, size=X_train.shape)
X_test_noise = X_test + 0.4 * np.random.normal(loc=0.0, scale=1.0, size=X_test.shape)

X_train_noise = np.clip(X_train_noise, 0.0, 1.0)
X_test_noise = np.clip(X_test_noise, 0.0, 1.0)

# Display the train data and a version of it with added noise
for i in range(5):
  plt.subplot(2,5,i+1)
  plt.imshow(X_train[i,:].reshape([28,28]), cmap='gray')
  plt.axis('off')
  plt.subplot(2,5,i+6)
  plt.imshow(X_train_noise[i,:].reshape([28,28]), cmap='gray')
  plt.axis('off')
plt.show()

# %%
print("il y a ", X_train.shape[0], "images de taille ", X_train.shape[1], "x", X_train.shape[2], "x", X_train.shape[3])
print("il y a  ", Y_train.shape[1], "classes")
# Out:
# il y a  6000 images de taille  28 x 28 x 1
# il y a   10 classes

# %% [markdown]
# La fonction np.clip permet de mettre les valeurs de la matrice entre 0 et 1.
#
# ### Définition du reseau

# %%
# partie encodeur


input = Input(shape=(28,28,1))
x = input
x = Convolution2D(32, kernel_size=(3,3), activation='relu',padding='same')(x)
x = MaxPooling2D(pool_size=(3,3),strides=2,padding='same')(x)


x = Convolution2D(32, kernel_size=(3,3), activation='relu',padding='same')(x)
x = MaxPooling2D(pool_size=(3,3),strides=2,padding='same')(x)


#partie decodeur : une convolution transposee avec stride 2

x = Conv2DTranspose(32, kernel_size=(3,3), strides=2, activation='relu',padding='same')(x)
x = Conv2DTranspose(32, kernel_size=(3,3), strides=2, activation='relu',padding='same')(x)

#ici, on esta 19x19x32
#une couche de convoluution pour avoir en sortie 1 image de taille 28x28 en niveau de gris
# 19 19 1 et on veut 28 28 1 en sortie : il faut donc un padding de 4
output = Convolution2D(1, kernel_size=(3,3), strides=1,padding='same', activation='linear')(x)



encodeur = Model(input, output)

#summary
encodeur.summary()

print("Nombre de paramètres : ", encodeur.count_params())
# Out:
# Model: "model_36"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_46 (InputLayer)       [(None, 28, 28, 1)]       0
#
#  conv2d_76 (Conv2D)          (None, 28, 28, 32)        320
#
#  max_pooling2d_56 (MaxPooli  (None, 14, 14, 32)        0
#  ng2D)
#
#  conv2d_77 (Conv2D)          (None, 14, 14, 32)        9248
#
#  max_pooling2d_57 (MaxPooli  (None, 7, 7, 32)          0
#  ng2D)
#
#  conv2d_transpose_40 (Conv2  (None, 14, 14, 32)        9248
#  DTranspose)
#
#  conv2d_transpose_41 (Conv2  (None, 28, 28, 32)        9248
#  DTranspose)
#
#  conv2d_78 (Conv2D)          (None, 28, 28, 1)         289
#
# =================================================================
# Total params: 28353 (110.75 KB)
# Trainable params: 28353 (110.75 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Nombre de paramètres :  28353

# %% [markdown]
# backbone = taille sortie encoder = 4 4 32

# %% [markdown]
# # Apprentissage

# %%
opt = keras.optimizers.Adam(learning_rate=0.0005)

encodeur.compile(loss="mse", optimizer=opt,metrics=['accuracy'])

#train : attention, l'erreur est entre l'input (bruité) et l'output (reconstruction)
history = encodeur.fit(X_train_noise, X_train, batch_size=128, epochs=10, verbose=1,validation_data=(X_test_noise, X_test))
affiche(history)
# Out:
# Epoch 1/10
# 47/47 [==============================] - 6s 110ms/step - loss: 0.0136 - accuracy: 0.8137 - val_loss: 0.0206 - val_accuracy: 0.8112
# Epoch 2/10
# 47/47 [==============================] - 5s 109ms/step - loss: 0.0127 - accuracy: 0.8140 - val_loss: 0.0203 - val_accuracy: 0.8111
# Epoch 3/10
# 47/47 [==============================] - 6s 121ms/step - loss: 0.0124 - accuracy: 0.8141 - val_loss: 0.0201 - val_accuracy: 0.8109
# Epoch 4/10
# 47/47 [==============================] - 5s 115ms/step - loss: 0.0122 - accuracy: 0.8142 - val_loss: 0.0198 - val_accuracy: 0.8108
# Epoch 5/10
# 47/47 [==============================] - 5s 113ms/step - loss: 0.0119 - accuracy: 0.8142 - val_loss: 0.0198 - val_accuracy: 0.8110
# Epoch 6/10
# 47/47 [==============================] - 5s 103ms/step - loss: 0.0116 - accuracy: 0.8143 - val_loss: 0.0194 - val_accuracy: 0.8110
# Epoch 7/10
# 47/47 [==============================] - 5s 104ms/step - loss: 0.0113 - accuracy: 0.8144 - val_loss: 0.0195 - val_accuracy: 0.8109
# Epoch 8/10
# 47/47 [==============================] - 5s 107ms/step - loss: 0.0111 - accuracy: 0.8145 - val_loss: 0.0192 - val_accuracy: 0.8113
# Epoch 9/10
# 47/47 [==============================] - 5s 105ms/step - loss: 0.0108 - accuracy: 0.8145 - val_loss: 0.0194 - val_accuracy: 0.8113
# Epoch 10/10
# 47/47 [==============================] - 5s 107ms/step - loss: 0.0106 - accuracy: 0.8146 - val_loss: 0.0192 - val_accuracy: 0.8107

# %%
#on predit sur les données de test
X_test_pred = encodeur.predict(X_test_noise)
# Out:
# 32/32 [==============================] - 0s 7ms/step

# %%
#on affiche les images bruitées, les images reconstruites et les images originales
plt.figure(figsize=(10,10))
for i in range(5):
  plt.subplot(3,5,i+1)
  plt.imshow(X_test_noise[i,:].reshape([28,28]), cmap='gray')
  plt.axis('off')


  plt.subplot(3,5,i+6)
  plt.imshow(X_test_pred[i,:].reshape([28,28]), cmap='gray')
  plt.axis('off')


  plt.subplot(3,5,i+11)
  plt.imshow(X_test[i,:].reshape([28,28]), cmap='gray')
  plt.axis('off')
plt.show()

# %% [markdown]
# # Variational Auto-encodeur

# %%
#on reprends MNIST


# load dataset
(X_train, y_train), (X_test, y_test) = load_data() # Chargement des données de MNIST
X_train, pipo, y_train, pipo = train_test_split(X_train, y_train, test_size=0.9)
X_test, pipo, y_test, pipo = train_test_split(X_test, y_test, test_size=0.9)



X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], X_train.shape[2], 1)
#APRES : (60000, 28, 28, 1)

X_test = X_test.reshape(X_test.shape[0], X_train.shape[1], X_train.shape[2], 1)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255


Y_train = tf.keras.utils.to_categorical(y_train, 10)
Y_test = tf.keras.utils.to_categorical(y_test, 10)

# %%
def sampling(mu_log_variance):
    mu, log_variance = mu_log_variance
    epsilon = tf.keras.backend.random_normal(shape=tf.keras.backend.shape(mu), mean=0.0, stddev=1.0)
    random_sample = mu + tf.keras.backend.exp(log_variance/2) * epsilon
    return random_sample


def loss_func(encoder_mu, encoder_log_variance):
    def vae_reconstruction_loss(y_true, y_predict):
        reconstruction_loss_factor = 1000
        reconstruction_loss = tf.keras.backend.mean(tf.keras.backend.square(y_true-y_predict), axis=[1, 2, 3])
        return reconstruction_loss_factor * reconstruction_loss

    def vae_kl_loss(encoder_mu, encoder_log_variance):
        kl_loss = -0.5 * tf.keras.backend.sum(1.0 + encoder_log_variance - tf.keras.backend.square(encoder_mu) - tf.keras.backend.exp(encoder_log_variance), axis=1)
        return kl_loss


    def vae_loss(y_true, y_predict):
        reconstruction_loss = vae_reconstruction_loss(y_true, y_predict)
        kl_loss = vae_kl_loss(y_true, y_predict)

        loss = reconstruction_loss + kl_loss
        return loss

    return vae_loss

# %%
#u encodeur)(x)

input = Input(shape=(28,28,1))
x = input


x = Convolution2D(32, kernel_size=(3,3), activation='relu',padding='same')(x)
x = MaxPooling2D(pool_size=(3,3),strides=2,padding='same')(x)


x = Convolution2D(32, kernel_size=(3,3), activation='relu',padding='same')(x)
x = MaxPooling2D(pool_size=(3,3),strides=2,padding='same')(x)

x=Flatten()(x)

#couche dense de taille 16
x=Dense(16, activation="relu")(x)

mu = Dense(2)(x)
log_variance = Dense(2)(x)
encoder_output = tf.keras.layers.Lambda(sampling)([ mu, log_variance])


#on definit le modele encodeur
encodeur = Model(input, encoder_output)

#summary

encodeur.summary()
# Out:
# Model: "model_41"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_52 (InputLayer)       [(None, 28, 28, 1)]          0         []
#
#  conv2d_89 (Conv2D)          (None, 28, 28, 32)           320       ['input_52[0][0]']
#
#  max_pooling2d_68 (MaxPooli  (None, 14, 14, 32)           0         ['conv2d_89[0][0]']
#  ng2D)
#
#  conv2d_90 (Conv2D)          (None, 14, 14, 32)           9248      ['max_pooling2d_68[0][0]']
#
#  max_pooling2d_69 (MaxPooli  (None, 7, 7, 32)             0         ['conv2d_90[0][0]']
#  ng2D)
#
#  flatten_35 (Flatten)        (None, 1568)                 0         ['max_pooling2d_69[0][0]']
#
#  dense_62 (Dense)            (None, 16)                   25104     ['flatten_35[0][0]']
#
#  dense_63 (Dense)            (None, 2)                    34        ['dense_62[0][0]']
#
#  dense_64 (Dense)            (None, 2)                    34        ['dense_62[0][0]']
#
#  lambda_3 (Lambda)           (None, 2)                    0         ['dense_63[0][0]',
#                                                                      'dense_64[0][0]']
#
# ==================================================================================================
# Total params: 34740 (135.70 KB)
# Trainable params: 34740 (135.70 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# - mu represente la moyenne du vecteur latent
# - sigma represente la variance.

# %%
print(mu.shape)
print(log_variance.shape)
print(encoder_output.shape)
# Out:
# (None, 2)
# (None, 2)
# (None, 2)

# %% [markdown]
# ## Decodeur
#
# Il prend en entree un vecteur de taille 2 et le transforme en une image de taille 28x28x1

# %%
#DECODEUR

x=Dense(7*7*32, activation="relu")(encoder_output)

#on reshape pour avoir 7 7 32
x=Reshape((7,7,32))(x)

#une couche de convolution transposee 
x=Conv2DTranspose(32, kernel_size=(3,3), strides=2, activation='relu',padding='same')(x)
x=Conv2DTranspose(32, kernel_size=(3,3), strides=2, activation='relu',padding='same')(x)

x= Convolution2D(1,kernel_size=(3,3),strides=1,activation='linear',padding='same')(x)
# on veut en sortie une image 28 28 1 

vae = Model(input, x)

vae.summary()
# Out:
# Model: "model_48"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_52 (InputLayer)       [(None, 28, 28, 1)]          0         []
#
#  conv2d_89 (Conv2D)          (None, 28, 28, 32)           320       ['input_52[0][0]']
#
#  max_pooling2d_68 (MaxPooli  (None, 14, 14, 32)           0         ['conv2d_89[0][0]']
#  ng2D)
#
#  conv2d_90 (Conv2D)          (None, 14, 14, 32)           9248      ['max_pooling2d_68[0][0]']
#
#  max_pooling2d_69 (MaxPooli  (None, 7, 7, 32)             0         ['conv2d_90[0][0]']
#  ng2D)
#
#  flatten_35 (Flatten)        (None, 1568)                 0         ['max_pooling2d_69[0][0]']
#
#  dense_62 (Dense)            (None, 16)                   25104     ['flatten_35[0][0]']
#
#  dense_63 (Dense)            (None, 2)                    34        ['dense_62[0][0]']
#
#  dense_64 (Dense)            (None, 2)                    34        ['dense_62[0][0]']
#
#  lambda_3 (Lambda)           (None, 2)                    0         ['dense_63[0][0]',
#                                                                      'dense_64[0][0]']
#
#  dense_71 (Dense)            (None, 1568)                 4704      ['lambda_3[0][0]']
#
#  reshape_8 (Reshape)         (None, 7, 7, 32)             0         ['dense_71[0][0]']
#
#  conv2d_transpose_58 (Conv2  (None, 14, 14, 32)           9248      ['reshape_8[0][0]']
#  DTranspose)
#
#  conv2d_transpose_59 (Conv2  (None, 28, 28, 32)           9248      ['conv2d_transpose_58[0][0]']
#  DTranspose)
#
#  conv2d_93 (Conv2D)          (None, 28, 28, 1)            289       ['conv2d_transpose_59[0][0]']
#
# ==================================================================================================
# Total params: 58229 (227.46 KB)
# Trainable params: 58229 (227.46 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# # VAE

# %%
#on realise l'apprentissage pour pouvoir mieux 

vae.compile(optimizer=keras.optimizers.Adam(learning_rate= 0.0005), loss=loss_func(mu, log_variance), metrics=['accuracy'])
vae.fit(X_train, X_train, epochs=50, batch_size=32, shuffle=True, validation_data=(X_test, X_test))
# Out:
# Epoch 1/50
# 188/188 [==============================] - 7s 30ms/step - loss: 73.2259 - accuracy: 0.8015 - val_loss: 64.9737 - val_accuracy: 0.7981
# Epoch 2/50
# 188/188 [==============================] - 5s 29ms/step - loss: 64.3887 - accuracy: 0.7984 - val_loss: 61.4353 - val_accuracy: 0.7967
# Epoch 3/50
# 188/188 [==============================] - 6s 31ms/step - loss: 59.7319 - accuracy: 0.7975 - val_loss: 58.3603 - val_accuracy: 0.7997
# Epoch 4/50
# 188/188 [==============================] - 5s 29ms/step - loss: 57.8683 - accuracy: 0.7981 - val_loss: 57.4029 - val_accuracy: 0.7988
# Epoch 5/50
# 188/188 [==============================] - 5s 28ms/step - loss: 56.9661 - accuracy: 0.7987 - val_loss: 56.6228 - val_accuracy: 0.8004
# Epoch 6/50
# 188/188 [==============================] - 5s 28ms/step - loss: 56.3081 - accuracy: 0.7988 - val_loss: 56.0182 - val_accuracy: 0.7989
# Epoch 7/50
# 188/188 [==============================] - 5s 28ms/step - loss: 55.7932 - accuracy: 0.7989 - val_loss: 55.3379 - val_accuracy: 0.8011
# Epoch 8/50
# 188/188 [==============================] - 5s 29ms/step - loss: 55.2434 - accuracy: 0.7989 - val_loss: 55.0583 - val_accuracy: 0.8011
# Epoch 9/50
# 188/188 [==============================] - 5s 29ms/step - loss: 54.7484 - accuracy: 0.7990 - val_loss: 54.3707 - val_accuracy: 0.7956
# Epoch 10/50
# 188/188 [==============================] - 5s 28ms/step - loss: 54.2694 - accuracy: 0.7988 - val_loss: 53.5326 - val_accuracy: 0.8005
# Epoch 11/50
# 188/188 [==============================] - 5s 28ms/step - loss: 53.7364 - accuracy: 0.7989 - val_loss: 53.2032 - val_accuracy: 0.8000
# Epoch 12/50
# 188/188 [==============================] - 5s 28ms/step - loss: 53.2851 - accuracy: 0.7989 - val_loss: 52.6270 - val_accuracy: 0.8008
# Epoch 13/50
# 188/188 [==============================] - 5s 29ms/step - loss: 52.8846 - accuracy: 0.7989 - val_loss: 52.0342 - val_accuracy: 0.7988
# Epoch 14/50
# 188/188 [==============================] - 5s 29ms/step - loss: 52.4003 - accuracy: 0.7987 - val_loss: 51.9061 - val_accuracy: 0.8014
# Epoch 15/50
# 188/188 [==============================] - 6s 30ms/step - loss: 52.0437 - accuracy: 0.7987 - val_loss: 51.4920 - val_accuracy: 0.7972
# Epoch 16/50
# 188/188 [==============================] - 7s 35ms/step - loss: 51.5720 - accuracy: 0.7985 - val_loss: 50.9948 - val_accuracy: 0.7987
# Epoch 17/50
# 188/188 [==============================] - 6s 31ms/step - loss: 51.3212 - accuracy: 0.7984 - val_loss: 50.9307 - val_accuracy: 0.8015
# Epoch 18/50
# 188/188 [==============================] - 5s 29ms/step - loss: 51.0105 - accuracy: 0.7982 - val_loss: 51.0177 - val_accuracy: 0.8024
# Epoch 19/50
# 188/188 [==============================] - 6s 30ms/step - loss: 50.7518 - accuracy: 0.7982 - val_loss: 50.3846 - val_accuracy: 0.7949
# Epoch 20/50
# 188/188 [==============================] - 6s 31ms/step - loss: 50.5425 - accuracy: 0.7981 - val_loss: 49.8226 - val_accuracy: 0.7956
# Epoch 21/50
# 188/188 [==============================] - 6s 31ms/step - loss: 50.2483 - accuracy: 0.7979 - val_loss: 49.5548 - val_accuracy: 0.7980
# Epoch 22/50
# 188/188 [==============================] - 6s 31ms/step - loss: 49.9582 - accuracy: 0.7981 - val_loss: 49.9671 - val_accuracy: 0.8006
# Epoch 23/50
# 188/188 [==============================] - 6s 33ms/step - loss: 49.8288 - accuracy: 0.7980 - val_loss: 49.8460 - val_accuracy: 0.8013
# Epoch 24/50
# 188/188 [==============================] - 6s 33ms/step - loss: 49.5364 - accuracy: 0.7980 - val_loss: 49.1376 - val_accuracy: 0.7978
# Epoch 25/50
# 188/188 [==============================] - 6s 33ms/step - loss: 49.4552 - accuracy: 0.7980 - val_loss: 49.0522 - val_accuracy: 0.7966
# Epoch 26/50
# 188/188 [==============================] - 6s 31ms/step - loss: 49.2923 - accuracy: 0.7981 - val_loss: 48.9823 - val_accuracy: 0.7965
# Epoch 27/50
# 188/188 [==============================] - 6s 31ms/step - loss: 49.1446 - accuracy: 0.7980 - val_loss: 48.7152 - val_accuracy: 0.7986
# Epoch 28/50
# 188/188 [==============================] - 6s 33ms/step - loss: 48.9405 - accuracy: 0.7981 - val_loss: 48.7386 - val_accuracy: 0.7996
# Epoch 29/50
# 188/188 [==============================] - 6s 31ms/step - loss: 48.7796 - accuracy: 0.7980 - val_loss: 48.7070 - val_accuracy: 0.7989
# Epoch 30/50
# 188/188 [==============================] - 6s 31ms/step - loss: 48.6974 - accuracy: 0.7981 - val_loss: 48.3605 - val_accuracy: 0.7994
# Epoch 31/50
# 188/188 [==============================] - 6s 31ms/step - loss: 48.5042 - accuracy: 0.7982 - val_loss: 48.4960 - val_accuracy: 0.7974
# Epoch 32/50
# 188/188 [==============================] - 6s 31ms/step - loss: 48.5076 - accuracy: 0.7980 - val_loss: 48.6439 - val_accuracy: 0.8018
# Epoch 33/50
# 188/188 [==============================] - 6s 31ms/step - loss: 48.3063 - accuracy: 0.7982 - val_loss: 49.1135 - val_accuracy: 0.8021
# Epoch 34/50
# 188/188 [==============================] - 6s 31ms/step - loss: 48.3196 - accuracy: 0.7983 - val_loss: 48.4142 - val_accuracy: 0.7965
# Epoch 35/50
# 188/188 [==============================] - 6s 31ms/step - loss: 48.1232 - accuracy: 0.7983 - val_loss: 48.1074 - val_accuracy: 0.8001
# Epoch 36/50
# 188/188 [==============================] - 6s 31ms/step - loss: 47.8932 - accuracy: 0.7984 - val_loss: 47.8319 - val_accuracy: 0.7994
# Epoch 37/50
# 188/188 [==============================] - 6s 31ms/step - loss: 47.7300 - accuracy: 0.7984 - val_loss: 48.1991 - val_accuracy: 0.8012
# Epoch 38/50
# 188/188 [==============================] - 6s 31ms/step - loss: 47.6845 - accuracy: 0.7984 - val_loss: 48.0179 - val_accuracy: 0.7977
# Epoch 39/50
# 188/188 [==============================] - 6s 31ms/step - loss: 47.5247 - accuracy: 0.7984 - val_loss: 47.5991 - val_accuracy: 0.7982
# Epoch 40/50
# 188/188 [==============================] - 6s 31ms/step - loss: 47.5629 - accuracy: 0.7984 - val_loss: 47.7435 - val_accuracy: 0.7989
# Epoch 41/50
# 188/188 [==============================] - 6s 31ms/step - loss: 47.5213 - accuracy: 0.7984 - val_loss: 48.5192 - val_accuracy: 0.8042
# Epoch 42/50
# 188/188 [==============================] - 6s 31ms/step - loss: 47.4293 - accuracy: 0.7985 - val_loss: 47.7007 - val_accuracy: 0.8004
# Epoch 43/50
# 188/188 [==============================] - 6s 33ms/step - loss: 47.2313 - accuracy: 0.7986 - val_loss: 48.3952 - val_accuracy: 0.8033
# Epoch 44/50
# 188/188 [==============================] - 7s 39ms/step - loss: 47.2324 - accuracy: 0.7985 - val_loss: 47.4320 - val_accuracy: 0.7972
# Epoch 45/50
# 188/188 [==============================] - 6s 32ms/step - loss: 47.0798 - accuracy: 0.7986 - val_loss: 47.8598 - val_accuracy: 0.8008
# Epoch 46/50
# 188/188 [==============================] - 6s 32ms/step - loss: 47.0410 - accuracy: 0.7986 - val_loss: 47.5382 - val_accuracy: 0.7951
# Epoch 47/50
# 188/188 [==============================] - 7s 39ms/step - loss: 46.9437 - accuracy: 0.7986 - val_loss: 47.5279 - val_accuracy: 0.7974
# Epoch 48/50
# 188/188 [==============================] - 8s 42ms/step - loss: 46.8522 - accuracy: 0.7987 - val_loss: 47.3698 - val_accuracy: 0.8011
# Epoch 49/50
# 188/188 [==============================] - 8s 45ms/step - loss: 46.7623 - accuracy: 0.7987 - val_loss: 47.6396 - val_accuracy: 0.8001
# Epoch 50/50
# 188/188 [==============================] - 7s 38ms/step - loss: 46.8379 - accuracy: 0.7987 - val_loss: 47.1725 - val_accuracy: 0.7970

# %%
#evaluation du modele
score = vae.evaluate(X_test, X_test, verbose=0)

print('Test loss:', score[0])
print('Test accuracy:', score[1])


#on predit sur les données de test
X_test_gen = vae.predict(X_test)
# Out:
# Test loss: 47.179534912109375
# Test accuracy: 0.7970268130302429
# 32/32 [==============================] - 0s 7ms/step

# %%
#on affiche les images bruitées, les images reconstruites et les images originales
random.seed(60)
#affiche random

plt.figure(figsize=(10,10))
indices = random.sample(range(0, X_test.shape[0]), 5)
print(indices)

for i in range(5):
  plt.subplot(2,5,i+1)
  plt.imshow(X_test[indices[i],:].reshape([28,28]), cmap='gray')
  plt.axis('off')


  plt.subplot(2,5,i+6)
  plt.imshow(X_test_gen[indices[i],:].reshape([28,28]), cmap='gray')
  plt.axis('off')
# Out:
# [315, 290, 591, 157, 271]

# %% [markdown]
# ![encodeur.png](attachment:encodeur.png)
# ![yarao.png](attachment:yarao.png)
